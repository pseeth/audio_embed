# %%
import librosa
from audio_embed import utilities
filename = librosa.util.example_audio_file()
reload(utilities)
#Apply a style sheet that makes audio elements stretch the page, and centers images.
utilities.apply_style()

#Load the librosa example audio file and embed it into the page. 
#The package converts it to mp3 to make the notebook more lightweight, as notebooks over 100MB DO NOT SAVE.
d, sr = librosa.load(filename)
utilities.audio(d, sr)

stft = librosa.stft(d)

#Separate it into two sources using some algorithm (in this case harmonic/percussive source separation)
harmonic, percussive = librosa.decompose.hpss(stft)

harmonic = librosa.istft(harmonic)
percussive = librosa.istft(percussive)

#Display the multitrack player which allows you to toggle between sources and the mixture.
utilities.multitrack([(harmonic, 'Harmonic'), (percussive, 'Percussive')], sr)
# Out:
#         <style>
#             audio {
#             width: 100% !important;
#         }
#         .output_png {
#             text-align: center !important;
#         }
#         </style>
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
#     <div id = 'DASLRUCIUY' class='audio-container' preload = 'auto' name='DASLRUCIUY'>
#
#         <audio name="Harmonic" url="data:audio/mpeg;base64,...">
#         </audio>
#
#         <audio name="Percussive" url="data:audio/mpeg;base64,...">
#         </audio>
#         </div><style>.inline{display:inline}.center{margin:0 auto}.float-left,.audio-container ul.tracks>li ul,.audio-container .track-name{display:inline;float:left}.float-right{display:inline;float:right}.hidden{display:none}.display-block,.bkg-list li a,.control-list>li>a,.audio-container ul.tracks>li ul>li>a,.audio-container .main-control ul>li>a,.control-list>li.solo a span,.audio-container ul.tracks>li ul>li.solo a span,.audio-container .main-control ul>li.solo a span,.audio-container ul.tracks>li{display:block}.fixed{position:fixed}.relative,.audio-container .main-control,.expandable>:first-child a{position:relative}.absolute,.audio-container .main-control ul,.audio-container .main-control .timebar-wrapper .timebar{position:absolute}.invisible{visibility:hidden}.no-overflow{overflow:hidden}.scroll{overflow:auto;scroll:auto}.inline-block-list,.control-list,.audio-container ul.tracks>li ul,.audio-container .main-control ul{margin:0;padding:0;border:0;overflow:hidden;*zoom:1}.inline-block-list li,.control-list li,.audio-container ul.tracks>li ul li,.audio-container .main-control ul li{list-style-image:none;list-style-type:none;margin-left:0;display:-moz-inline-stack;display:inline-block;vertical-align:middle;*vertical-align:auto;zoom:1;*display:inline;white-space:nowrap}.inline-block-list-item,.control-list>li,.audio-container ul.tracks>li ul>li,.audio-container .main-control ul>li,.control-list>li>a,.audio-container ul.tracks>li ul>li>a,.audio-container .main-control ul>li>a{list-style-image:none;list-style-type:none;margin-left:0;display:-moz-inline-stack;display:inline-block;vertical-align:middle;*vertical-align:auto;zoom:1;*display:inline;white-space:nowrap}@-webkit-keyframes open-sub-expand{0%{opacity:0;max-height:0}100%{opacity:1;max-height:3000px;display:block}}@-moz-keyframes open-sub-expand{from{opacity:0;max-height:0;display:none}to{opacity:1;max-height:3000px;display:block}}@-webkit-keyframes close-sub-expand{0%{opacity:1;max-height:3000px;display:block}100%{opacity:0;max-height:0;display:none}}@-moz-keyframes close-sub-expand{from{opacity:1;max-height:3000px;display:block}to{opacity:0;max-height:0;display:none}}.t-left,.bkg-list li a{text-align:left}.t-right{text-align:right}.t-center{text-align:center;vertical-align:middle}.t-justify{text-align:justify}.t-hide,.control-list>li>a,.audio-container ul.tracks>li ul>li>a,.audio-container .main-control ul>li>a,.control-list>li.solo a span,.audio-container ul.tracks>li ul>li.solo a span,.audio-container .main-control ul>li.solo a span,.audio-container .loader,.audio-container .loading-link,.audio-container .status{text-indent:-3333px;overflow:hidden}.t-caps,.button{text-transform:uppercase}.t-lower{text-transform:lowercase}.t-no-select{-webkit-user-select:none;-khtml-user-select:none;-moz-user-select:none;-o-user-select:none;user-select:none}.no-background{background:none !important}body.high-graphics .css-transition-all,body.high-graphics .bkg-link,body.high-graphics .bkg-list li a,.bkg-list li body.high-graphics a,body.high-graphics .button,body.high-graphics .control-list>li>a,body.high-graphics .audio-container ul.tracks>li ul>li>a,.audio-container ul.tracks>li body.high-graphics ul>li>a,body.high-graphics .audio-container .main-control ul>li>a,.audio-container .main-control body.high-graphics ul>li>a,body.high-graphics .audio-container .tracks,.audio-container body.high-graphics .tracks,body.high-graphics .audio-container .main-control,.audio-container body.high-graphics .main-control,body.high-graphics .audio-container .loading-link,.audio-container body.high-graphics .loading-link,body.high-graphics .basic-expandable .icon-expand,.basic-expandable body.high-graphics .icon-expand,body.high-graphics .expandable .icon-expand,.expandable body.high-graphics .icon-expand,body.high-graphics .basic-expandable .icon-reduce,.basic-expandable body.high-graphics .icon-reduce,body.high-graphics .expandable .icon-reduce,.expandable body.high-graphics .icon-reduce,body.high- ...
# container.prepend('<div class="main-control"><ul class="control"><li class="play"><a href="javascript://">play</a></li> <li class="pause"><a href="javascript://">pause</a></li> <li class="stop"><a href="javascript://">stop</a></li> <li class="repeat"><a href="javascript://">repeat</a></li></ul><div class="timebar-wrapper"><div class="timebar"></div></div></div>');var audioTags=container.find("audio");audioTags.detach();container.append('<ul class="tracks"></ul>');var containerTracks=container.find('.tracks');audioTags.each(function(i){containerTracks.append('<li class="track"><ul class="control"><li class="mute"><a href="javascript://">mute</a></li><li class="solo"><a href="javascript://"><span></span></a></li></ul><span class="status"></span><audio index="'+i+'" container="'+containerID+'"><source src ="'+$(this).attr("url")+'"/>Your browser does not support the audio element.</audio><span class="track-name">'+$(this).attr("name")+'</span>'+'</li>');});container.append('<span class="loader"></span>');if(!preload){container.append('<a class="loading-link" href="javascript://"></a>').addClass("waiting");}
# audioTags.remove();};initPlayer=function(containerID){var container=$("#"+containerID);generateHtml(container);DASLRUCIUY_player[containerID]={tracks:Array(),playButton:container.find(".main-control .play"),pauseButton:container.find(".main-control .pause"),stopButton:container.find(".main-control .stop"),repeatButton:container.find(".main-control .repeat"),timebar:container.find(".main-control .timebar"),timebarWrapper:container.find(".main-control .timebar-wrapper"),firstTrack:null,loadedAudio:0,playing:false,repeat:false};DASLRUCIUY_player[containerID].playButton.attr('container',containerID);DASLRUCIUY_player[containerID].pauseButton.attr('container',containerID);DASLRUCIUY_player[containerID].stopButton.attr('container',containerID);DASLRUCIUY_player[containerID].repeatButton.attr('container',containerID);DASLRUCIUY_player[containerID].timebar.attr('container',containerID);DASLRUCIUY_player[containerID].timebarWrapper.attr('container',containerID);container.find(".tracks audio").each(function(i,value){var that=$(this);that.attr('container',containerID);DASLRUCIUY_player[containerID].tracks.push(that[0]);that[0].load();that[0].addEventListener("canplaythrough",function(){DASLRUCIUY_player[containerID].loadedAudio++;if(DASLRUCIUY_player[containerID].loadedAudio==DASLRUCIUY_player[containerID].tracks.length)container.trigger("ready");},false);that[0].addEventListener("error",function(){container.trigger("error",i+1);},false);that.attr("index",i);});DASLRUCIUY_player[containerID].trackCount=DASLRUCIUY_player[containerID].tracks.length;DASLRUCIUY_player[containerID].firstTrack=DASLRUCIUY_player[containerID].tracks[0];container.on("ready",function(){$(this).addClass("ready");});container.on("error",function(e,i){$(this).addClass("error");$(this).find('.track:nth-child('+i+')').addClass("error");});container.on('click','.tracks .track:not(.locked):not(.solo) .mute:not(.active) > a',function(){var dad=$(this).parent();dad.addClass("active");dad.closest(".track").addClass("mute");var track=$(this).closest('.track').find('audio:first')[0];track.volume=0;});container.on('click','.tracks .track:not(.locked):not(.solo) .mute.active > a',function(){var dad=$(this).parent();dad.removeClass("active");dad.closest(".track").removeClass("mute");var track=$(this).closest('.track').find('audio:first')[0];track.volume=1;});container.on('click','.tracks .solo:not(.active) > a',function(){var dad=$(this).parent();dad.closest('.tracks').find(".track").removeClass("solo").addClass("locked").each(function(){$(this).find(".solo.active").removeClass("active");var track=$(this).find('audio:first')[0];track.volume=0;});dad.addClass("active");var track=dad.closest(".track").addClass("solo").removeClass("locked").find('audio:first')[0];track.volume=1;});container.on('click','.tracks .solo.active > a',function(){var dad=$(this).parent();dad.closest('.tracks').find(".track").removeClass("locked solo").each(function(){$(this).find(".solo.active").removeClass("active");var track=$(this).find('audio:first')[0];if($(this).hasClass("mute"))
# track.volume=0;else
# track.volume=1;});dad.removeClass("active");});container.on('click','.main-control .play:not(.active)',function(){var containerID=$(this).attr('container');DASLRUCIUY_player[containerID].pauseButton.removeClass("active");DASLRUCIUY_player[containerID].playButton.addClass("active");$.each(DASLRUCIUY_player[containerID].tracks,function(){this.play();});DASLRUCIUY_player[containerID].playing=true;});container.on('click','.loading-link',function(){var container=$(this).closest(".audio-container");container.removeClass("waiting").find('audio').each(function(){$(this).attr("src",$(this).attr("url"));});});container.on('click','.main-control .repeat',function(){var containerID=$(this).attr('container');$(this).toggleClass("active");DASLRUCIUY_player[containerID].repeat=$(this).hasClass("active");});container.on('click','.main-control .play.active + .pause:not(.active)',function(){var containerID=$(this).attr('container');DASLRUCIUY_player[containerID].playButton.removeClass("active");DASLRUCIUY_player[containerID].pauseButton.addClass("active");$.each(DASLRUCIUY_player[containerID].tracks,function(){this.pause();});DASLRUCIUY_player[containerID].playing=false;});container.on('click','.main-control .stop',function(){var containerID=$(this).attr('container');DASLRUCIUY_player[containerID].playButton.removeClass("active");DASLRUCIUY_player[containerID].pauseButton.removeClass("active");$.each(DASLRUCIUY_player[containerID].tracks,function(){this.pause();this.currentTime=0;});DASLRUCIUY_player[containerID].playing=false;});container.on('click','.main-control .timebar-wrapper',function(e){var containerID=$(this).attr('container');DASLRUCIUY_player[containerID].tracks[0].pause();var myWidth=e.pageX-DASLRUCIUY_player[containerID].timebar.offset().left;var widthPercent=(myWidth*100)/DASLRUCIUY_player[containerID].timebarWrapper.width();timePercent=DASLRUCIUY_player[containerID].firstTrack.duration*widthPercent/100;DASLRUCIUY_player[containerID].timebar.css('width',widthPercent+'%');for(var i=1;i<DASLRUCIUY_player[containerID].tracks.length;i++){var trackI=DASLRUCIUY_player[containerID].tracks[i];trackI.currentTime=timePercent;}
# DASLRUCIUY_player[containerID].tracks[0].currentTime=timePercent;if(DASLRUCIUY_player[containerID].playing==true)DASLRUCIUY_player[containerID].tracks[0].play();});$(DASLRUCIUY_player[containerID].tracks[0]).bind('timeupdate',function(){var containerID=$(this).attr('container');DASLRUCIUY_player[containerID].timebar.css('width',((DASLRUCIUY_player[containerID].firstTrack.currentTime*100)/DASLRUCIUY_player[containerID].firstTrack.duration)+'%');});$(DASLRUCIUY_player[containerID].tracks[0]).bind('ended',function(){var containerID=$(this).attr('container');DASLRUCIUY_player[containerID].stopButton.click();if(DASLRUCIUY_player[containerID].repeat)
# DASLRUCIUY_player[containerID].playButton.click();});};DASLRUCIUY_player={};initPlayer('DASLRUCIUY');</script>
